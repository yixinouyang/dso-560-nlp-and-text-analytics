# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# read txt file

good_reviews_df = pd.read_csv('good_amazon_toy_reviews.txt', sep="\n", header=None, names=["line"])
poor_reviews_df = pd.read_csv('poor_amazon_toy_reviews.txt', sep="\n", header=None, names=["line"])

# %%
# remove punctuation
good_reviews_df['no_punctuation'] = good_reviews_df['line'].str.replace(r'(<br />|['+string.punctuation+r'])',' ')
poor_reviews_df['no_punctuation'] = poor_reviews_df['line'].str.replace(r'(<br />|['+string.punctuation+r'])',' ')

# lower case
good_reviews_df['lower_case'] = good_reviews_df['no_punctuation'].str.lower()
poor_reviews_df['lower_case'] = poor_reviews_df['no_punctuation'].str.lower()

# stopword
stopword_list = stopword_list = stopwords.words('english')
good_reviews_df['stopword'] = good_reviews_df['lower_case'].str.replace(
    r'\b('+'|'.join(stopword_list)+r')\b','')
poor_reviews_df['stopword'] = poor_reviews_df['lower_case'].str.replace(
    r'\b('+'|'.join(stopword_list)+r')\b','')

# %%
def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

# %%
# reduce lengthening
good_reviews_df['short'] = good_reviews_df['stopword'].apply(reduce_lengthening)
poor_reviews_df['short'] = poor_reviews_df['stopword'].apply(reduce_lengthening)

# %%
lemmatizer = WordNetLemmatizer()
def lemma(s):
    l = [lemmatizer.lemmatize(word) for word in word_tokenize(s)]
    return ' '.join(l)

# %%
good_reviews_df['lemma'] = good_reviews_df['short'].apply(lemma)
poor_reviews_df['lemma'] = poor_reviews_df['short'].apply(lemma)

# %%
stemmer = PorterStemmer()
def stem(s):
    l = [stemmer.stem(word) for word in word_tokenize(s)]
    return ' '.join(l)

# %%
good_reviews_df['stem'] = good_reviews_df['short'].apply(stem)
poor_reviews_df['stem'] = poor_reviews_df['short'].apply(stem)

# %%
good_reviews_df
# Out:
#                                                      line  \
# 0                                            Excellent!!!
# 1       Great quality wooden track (better than some o...
# 2       my daughter loved it and i liked the price and...
# 3       Great item. Pictures pop thru and add detail a...
# 4                         I was pleased with the product.
# ...                                                   ...
# 102183                                           fun game
# 102184                               Nice kit,well priced
# 102185                    Does what it is supposed to do.
# 102186  Grandson loves playing with these police figur...
# 102187                      My grandson loves littleBits!
#
#                                            no_punctuation  \
# 0                                            Excellent
# 1       Great quality wooden track  better than some o...
# 2       my daughter loved it and i liked the price and...
# 3       Great item  Pictures pop thru and add detail a...
# 4                         I was pleased with the product
# ...                                                   ...
# 102183                                           fun game
# 102184                               Nice kit well priced
# 102185                    Does what it is supposed to do
# 102186  Grandson loves playing with these police figur...
# 102187                      My grandson loves littleBits
#
#                                                lower_case  \
# 0                                            excellent
# 1       great quality wooden track  better than some o...
# 2       my daughter loved it and i liked the price and...
# 3       great item  pictures pop thru and add detail a...
# 4                         i was pleased with the product
# ...                                                   ...
# 102183                                           fun game
# 102184                               nice kit well priced
# 102185                    does what it is supposed to do
# 102186  grandson loves playing with these police figur...
# 102187                      my grandson loves littlebits
#
#                                                  stopword  \
# 0                                            excellent
# 1       great quality wooden track  better   others   ...
# 2        daughter loved    liked  price   came   rathe...
# 3       great item  pictures pop thru  add detail    3...
# 4                                      pleased   product
# ...                                                   ...
# 102183                                           fun game
# 102184                               nice kit well priced
# 102185                                        supposed
# 102186       grandson loves playing   police figurines……
# 102187                         grandson loves littlebits
#
#                                                     short  \
# 0                                             excellent
# 1       great quality wooden track  better  others  tr...
# 2        daughter loved  liked  price  came  rather  s...
# 3       great item  pictures pop thru  add detail  34 ...
# 4                                       pleased  product
# ...                                                   ...
# 102183                                           fun game
# 102184                               nice kit well priced
# 102185                                         supposed
# 102186        grandson loves playing  police figurines……
# 102187                         grandson loves littlebits
#
#                                                     lemma  \
# 0                                               excellent
# 1       great quality wooden track better others tried...
# 2       daughter loved liked price came rather shoppin...
# 3       great item picture pop thru add detail 34 pain...
# 4                                         pleased product
# ...                                                   ...
# 102183                                           fun game
# 102184                               nice kit well priced
# 102185                                           supposed
# 102186           grandson love playing police figurines……
# 102187                           grandson love littlebits
#
#                                                      stem
# 0                                                   excel
# 1       great qualiti wooden track better other tri pe...
# 2       daughter love like price came rather shop ton ...
# 3       great item pictur pop thru add detail 34 paint...
# 4                                           pleas product
# ...                                                   ...
# 102183                                           fun game
# 102184                                nice kit well price
# 102185                                             suppos
# 102186               grandson love play polic figurines……
# 102187                            grandson love littlebit
#
# [102188 rows x 7 columns]

# %% [markdown]
# # Explanation
#
# Using the **`poor_amazon_toy_reviews.txt`** and **`good_amazon_toy_reviews.txt`** datasets, clean and parse the text reviews. Explain the decisions you make:
# - why remove/keep stopwords?
#
# **stopwords which have high tf but low idf don't have too much meaning, so they are useless for our analysis and should be removed**
#
# - stemming versus lemmatization?
#
# **at first I wanted lemmatization since it trims less and the word will contain more meaning than stemming, while later I found the dimensionality is too high so I had to use stemming to lower the number of features**
#
# - regex cleaning and substitution?
#
# **use regex to remove punctuations and common stopwords**
#
# - adding in custom stopwords?
#
# **for good review we better remove good word like 'good','great','love'**
#
# **for poor review we better remove bad word like**
#
#
# - what `n` for your `n-grams`?
#
# **(3,4) seems more meaningful**
#
# - which words to collocate together?
#
# **it's determined by ngram range and we can see the result in the table above**

# %%
def tfidf(corpus,ngram_range,stop_words):
    vectorizer = TfidfVectorizer(ngram_range=ngram_range,
                             token_pattern=r'\b[a-zA-Z]{3,}\b',
                             min_df=0.001,
                             stop_words=stop_words)
    X = vectorizer.fit_transform(corpus)
    terms = vectorizer.get_feature_names()
    tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms).sum(axis=1)
    score = pd.DataFrame(tf_idf, columns=["score"])
    score.sort_values(by="score", ascending=False, inplace=True)
    return score

# %%
tfidf(good_reviews_df['stem'],ngram_range=(2,3),stop_words=['love','good','great'])
# Out:
#                                 score
# year old                  3113.943085
# well made                 1313.729694
# highli recommend           799.183031
# fast ship                  728.308912
# lot fun                    717.357632
# ...                               ...
# discount rate               43.520015
# receiv product free         40.970739
# price exchang               39.304921
# product discount exchang    37.420996
# free exchang honest         34.349972
#
# [459 rows x 1 columns]

# %%
tfidf(good_reviews_df['stem'],ngram_range=(3,4),stop_words=['love','good','great'])
# Out:
#                                       score
# year old grandson                561.844408
# year old son                     535.944025
# year old daughter                517.684359
# year old granddaught             350.052407
# easi put togeth                  340.743145
# two year old                     330.289651
# bought year old                  297.872449
# one year old                     252.746750
# would definit recommend          237.065236
# three year old                   231.400840
# gift year old                    215.663496
# honest unbias review             212.914807
# would highli recommend           206.318511
# exchang honest review            206.100470
# american girl doll               191.159465
# four year old                    181.827167
# year old nephew                  180.021755
# price fast ship                  164.000000
# last long time                   161.060493
# year old play                    157.685262
# receiv product discount          153.607523
# exchang honest unbias            151.424571
# year old niec                    149.513635
# worth everi penni                138.505886
# year old birthday                135.618902
# five year old                    134.834309
# year old boy                     131.436596
# exchang honest unbias review     130.468700
# would recommend anyon            129.798987
# perfect year old                 119.472096
# well worth money                 114.052432
# cute well made                   113.904630
# discount exchang honest          112.628757
# got year old                     112.595338
# son birthday parti               105.516276
# look like pictur                 102.503849
# six year old                     101.015665
# fine motor skill                 100.264884
# old year old                      90.239708
# year old year                     84.030854
# receiv product free               84.001256
# year old year old                 71.928084
# free exchang honest               64.362098
# product discount exchang          56.846069
# receiv product discount exchang   51.344566

# %% [markdown]
# **From tfidf of good reviews we learn that customers like it beacuse it's an easy-put-together toy for their little kid or grandkid as a birthday present. The shipping is fast and they got discount.**

# %%
tfidf(poor_reviews_df['stem'],ngram_range=(3,4),stop_words=['poor','bad','zero'])
# Out:
#                              score
# broke first day          51.288028
# total wast money         43.818158
# complet wast money       42.610187
# wast time money          41.652088
# first time use           34.250543
# look noth like           33.509598
# year old son             31.294345
# look like pictur         29.232070
# broke first time         27.994626
# noth like pictur         26.450489
# would give star          25.784286
# get money back           25.732787
# year old grandson        25.493449
# year old daughter        25.356050
# broke within minut       22.924811
# would recommend anyon    20.193049
# buy wast money           19.399570
# would recommend product  19.128814
# two year old             19.127596
# buy anoth one            18.991607
# work wast money          18.690395
# bought son birthday      18.602385
# give one star            18.152836
# broke right away         18.000000
# broke first use          17.742997
# save money buy           17.588004
# could give star          17.478239
# bought year old          17.347048
# one year old             16.926356
# guess get pay            16.415973
# want money back          16.249795
# would never buy          16.179876
# disappoint year old      16.119185
# wast money buy           15.568577
# fell apart within        15.000000
# brand new batteri        14.733331
# broke within week        14.712552
# would recommend buy      14.448097
# look noth like pictur    14.360829
# dont wast money          14.131115
# year old play            14.074733
# start fall apart         14.000000
# give star would          13.751352
# son birthday parti       13.734042
# broke within day         13.724810
# three year old           13.490004
# four year old            13.439841
# year old love            13.393976
# year old granddaught     13.326042
# broke within first       13.287286
# big wast money           12.195685
# year old birthday        12.099049
# worst product ever       12.040268
# first day use            12.035974
# could give star would    11.891978
# pleas wast money         11.791740
# horribl wast money       11.750354
# wast money bought        11.456235
# wish could give          11.415659
# year old could           10.958287

# %% [markdown]
# **From tfidf of poor reviews we learn that these customers buy this toy for the same usage like the other group, their main complaints is the poor quaility of this product**

# %% [markdown]
# # Explanation
#
# Explain to what degree the TF-IDF findings make sense - what are its limitations?
#
# **It makes sense, but still has some limitations. For example, different n-grams ranges return very different results, and it's difficlut to decide which one is better. Also, because of high dimensionality I have to do more aggressive removel like min_df, which might lose valueable information**

# %%
catalog_df = pd.read_csv('truncated_catalog.csv')

# %%
def is_womens_clothing(line):
    for i in line:
        if re.search(r'\bm[ae]n|kid|girl|boy|\bmale|baby',str(i).lower()):
            return False
    return True

catalog_df['is_womens_clothing'] = catalog_df.apply(is_womens_clothing, axis=1)

# %%
def category(line):
    for i in line:
        if re.search(r'bottom',str(i).lower()):
            return 'Bottom'
        if re.search(r'one ?piece',str(i).lower()):
            return 'One Piece'
        if re.search(r'shoe',str(i).lower()):
            return 'Shoe'
        if re.search(r'handbag',str(i).lower()):
            return 'Handbag'
        if re.search(r'scarf',str(i).lower()):
            return 'Scarf'
    return ''

catalog_df['category'] = catalog_df.apply(category, axis=1)

# %%
color_list = ['Beige', 'Black', 'Blue', 'Brown', 'Burgundy', 'Gold', 'Gray', 'Green', 'Multi', 'Navy', 'Neutral', 'Orange', 'Pinks', 'Purple', 'Red', 'Silver', 'Teal', 'White', 'Yellow']

# %%
def color(line):
    s = set()
    for i in line:
        for color in color_list:
            if re.search(color.lower(),str(i).lower()):
                s.add(color)
    return list(s)

catalog_df['color'] = catalog_df.apply(color, axis=1)

# %%
catalog_df
# Out:
#                                 brand  \
# 0                                FILA
# 1                              CHANEL
# 2                               Frame
# 3                 Lilly Pulitzer Kids
# 4                         Kissy Kissy
# ...                               ...
# 42368                    Mara Hoffman
# 42369  Philosophy di Lorenzo Serafini
# 42370                   Vanessa Bruno
# 42371                       Eve Denim
# 42372                            FILA
#
#                                                     name  \
# 0                              Original Fitness Sneakers
# 1                                                    HAT
# 2                                 Petit Oval Buckle Belt
# 3      Little Gir's & Girl's Ariana One-Piece UPF 50+...
# 4      Baby Girl's Endearing Elephants Pima Cotton Co...
# ...                                                  ...
# 42368           Atlas oversized belted mélange wool coat
# 42369              Cropped crochet-trimmed georgette top
# 42370                    Juna cotton-corduroy mini skirt
# 42371                 Annabel Rigid Mid-Rise Skinny Jean
# 42372                    Kessler Colorblock Track Jacket
#
#                                              description  \
# 0      Vintage Fitness leather sneakers with logo pri...
# 1                                                    NaN
# 2      A Timeless Leather Belt Crafted From Smooth Co...
# 3      Pretty ruffle sleeves and trim elevate essenti...
# 4      Versatile convertible gown with elephant applique
# ...                                                  ...
# 42368  Mélange beige and cream wool Button fastenings...
# 42369  Cream georgette Ties at neck, concealed hook f...
# 42370  Sand cotton-corduroy Concealed hook and zip fa...
# 42371  Although mom jeans and boyfriend jeans are all...
# 42372  ONLY AT SAKS. Ultra-sporty nylon track jacket ...
#
#                                           brand_category  \
# 0                     TheMensStore/Shoes/Sneakers/LowTop
# 1                                                Unknown
# 2                                            Accessories
# 3      JustKids/Girls214/Girls/SwimwearCoverups,JustK...
# 4      JustKids/Baby024months/InfantGirls/FootiesRompers
# ...                                                  ...
# 42368                            Clothing / Coats / Long
# 42369                          Clothing / Tops / Blouses
# 42370                           Clothing / Skirts / Mini
# 42371                               women:CLOTHING:JEANS
# 42372  TheMensStore/Apparel/Outerwear/LightweightJackets
#
#                                      brand_canonical_url  \
# 0      https://www.saksfifthavenue.com/fila-original-...
# 1      https://www.saksfifthavenue.com/chanel-hat/pro...
# 2      https://frame-store.com/products/petit-oval-bu...
# 3      https://www.saksfifthavenue.com/lilly-pulitzer...
# 4      https://www.saksfifthavenue.com/kissy-kissy-ba...
# ...                                                  ...
# 42368  https://www.net-a-porter.com/us/en/product/117...
# 42369  https://www.net-a-porter.com/us/en/product/111...
# 42370  https://www.net-a-porter.com/us/en/product/116...
# 42371  https://pink.modaoperandi.com/eve-denim-r20/an...
# 42372  https://www.saksfifthavenue.com/fila-kessler-c...
#
#                                                  details  \
# 0      Leather/synthetic upper\nLace-up closure\nText...
# 1                                      WOOL TWEED & FELT
# 2                                                    NaN
# 3      Scoopneck\nAdjustable straps\nFlutter sleeves\...
# 4      V-neckline\nLong sleeves\nFront snap closure\n...
# ...                                                  ...
# 42368  Fits true to size, take your normal size \nDes...
# 42369  Fits true to size, take your normal size \nInt...
# 42370  Fits true to size, take your normal size \nTho...
# 42371  Button and zip fastening \nComposition: 98% co...
# 42372  Attached drawstring hood\nStand collar\nLong s...
#
#                                                      tsv  is_womens_clothing  \
# 0      'design':12 'fila':1A 'fit':3A,6 'leather':7 '...               False
# 1                                   'chanel':1A 'hat':2A                True
# 2      'belt':5A,9 'buckl':4A,21 'cowhid':13 'craft':...                True
# 3      '50':14A 'allov':28 'ariana':9A 'color':27 'el...               False
# 4      'appliqu':17 'babi':3A 'convert':10A,13 'cotto...               False
# ...                                                  ...                 ...
# 42368  '100':21 'atlas':3A 'beig':10 'belt':5A 'breas...                True
# 42369  '100':21 'back':20 'conceal':16 'cream':11 'cr...                True
# 42370  '100':20 '35':25 '65':23 'acet':24 'back':19 '...                True
# 42371  'add':36 'although':10 'annabel':3A,40 'boyfri...               False
# 42372  'colorblock':3A 'detail':18 'fila':1A 'jacket'...                True
#
#       category          color
# 0         Shoe             []
# 1                          []
# 2               [Multi, Gold]
# 3                          []
# 4       Bottom             []
# ...        ...            ...
# 42368                 [Beige]
# 42369                      []
# 42370                      []
# 42371                      []
# 42372                      []
#
# [42373 rows x 10 columns]
